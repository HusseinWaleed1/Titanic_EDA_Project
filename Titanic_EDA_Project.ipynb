# %% [markdown]
# <a href="https://colab.research.google.com/github/HusseinWaleed1/Titanic_EDA_Project/blob/main/Titanic_EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys  # For system-specific functions and parameters
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  # For advanced and beautiful statistical visualizations
sns.set()  # Set default Seaborn style for better-looking plots

# %% [markdown]
# importing libararies

# %%
df=pd.read_csv('/content/train.csv')
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#If there are any duplicates, we will drop them:
df.drop_duplicates(inplace=True)

# %%
# checking missing value
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Calculate the percentage of missing values in each column (rounded to 2 decimal places)
round(df.isna().mean() * 100, 2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.dropna(subset=['Embarked'],inplace=True)

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
round(df.isna().mean() * 100, 2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.91
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.28
# Embarked        0.00
# dtype: float64

# %%
df.Age.hist(bins=20) # bins=20 = تعني إنك هتقسم البيانات إلى 20 فئة (bins) على محور X.
# Out:
# <Axes: >

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                Name   Sex  Age  SibSp  \
# 760          761         0       3  Garfirth, Mr. John  male  NaN      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 760      0  358585  14.5   NaN        S

# %%
df[df['Sex']=='female'].Age.median() # Calculate the median age for females
# Out:
# 27.0

# %%
df[df['Sex']=='male'].Age.median() # calculate the median age for males
# Out:
# 29.0

# %%
print(df[df['Pclass'] == 1].Age.median()) # calculate the median age for pclass 1
print(df[df['Pclass'] == 2].Age.median()) # calculate the median age for pclass 2
print(df[df['Pclass'] == 3].Age.median()) # calculate the median age for pclass 3
# Out:
# 37.0
# 29.0
# 24.0

# %%
print(df[(df['Pclass'] == 1) & (df['Sex'] == 'female')].Age.median()) # calculate the median for p class 1 and female
print(df[(df['Pclass'] == 1) & (df['Sex'] == 'male')].Age.median())
print(df[(df['Pclass'] == 2) & (df['Sex'] == 'female')].Age.median())
print(df[(df['Pclass'] == 2) & (df['Sex'] == 'male')].Age.median())
print(df[(df['Pclass'] == 3) & (df['Sex'] == 'female')].Age.median())
print(df[(df['Pclass'] == 3) & (df['Sex'] == 'male')].Age.median())
# Out:
# 35.0
# 40.0
# 28.0
# 30.0
# 21.5
# 25.0

# %%
df.groupby(['Pclass','Sex'])['Age'].median()
# Out:
# Pclass  Sex
# 1       female    35.0
#         male      40.0
# 2       female    28.0
#         male      30.0
# 3       female    21.5
#         male      25.0
# Name: Age, dtype: float64

# %%
# filling missing values of age based on Pclass and Sex
df['Age'] = df.groupby(['Pclass', 'Sex'])['Age'].transform(lambda x: x.fillna(x.median()))

# %%
print(df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
# Drop Unnecessary columns
df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
# Rename Columns
#df.rename(columns={'Survived': 'survived', 'Pclass': 'pclass', 'SibSp': 'brothers', 'Parch': 'parch'}, inplace=True)
df.columns = df.columns.str.lower()

# %%
df.sample()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked
# 218         1       1  female  32.0      0      0  76.2917        C

# %% [markdown]
# Univariate

# %%
# Count the number of survivors (1) and non-survivors (0)
df.survived.value_counts()
# Out:
# survived
# 0    549
# 1    340
# Name: count, dtype: int64

# %%
# caluculate the percentage for survived & unsurvived
df.survived.value_counts() / len(df)*100   # shape[0]
# Out:
# survived
# 0    61.754781
# 1    38.245219
# Name: count, dtype: float64

# %%
# Get the percentage of survivors and non-survivors
# Calculate the proportion of survivors and non-survivors
df.survived.value_counts(normalize=True)
# Out:
# survived
# 0    0.617548
# 1    0.382452
# Name: proportion, dtype: float64

# %%
sns.countplot(x='survived', data=df);

# %%
df.pclass.value_counts(normalize=True)
# Out:
# pclass
# 3    0.552306
# 1    0.240720
# 2    0.206974
# Name: proportion, dtype: float64

# %%
df.sex.value_counts(normalize=True)
# Out:
# sex
# male      0.649044
# female    0.350956
# Name: proportion, dtype: float64

# %%
# Show the proportion of passengers by number of siblings/spouses aboard
df.sibsp.value_counts(normalize=True)
# Out:
# sibsp
# 0    0.681665
# 1    0.235096
# 2    0.031496
# 4    0.020247
# 3    0.017998
# 8    0.007874
# 5    0.005624
# Name: proportion, dtype: float64

# %%
# Proportion of passengers by number of siblings/spouses aboard (sibsp)
# 0 → passengers who were alone (single travelers) → ~68%
# 1 → with 1 sibling or spouse → ~23%
# 2 → with 2 siblings/spouses → ~3%
# 3, 4, 5 → fewer passengers with more family members
# 8 → very rare cases (large families)

# %%
col='Age'
col2 = 'Sex'
print(f'### {col}, {col2} ###')
print('###', col, '###')
print('### {} , {} ###'.format(col, col2))
# Out:
# ### Age, Sex ###
# ### Age ###
# ### Age , Sex ###

# %%
def explore_categorical(df, col):
    print(f'### {col} ###')
    print(df[col].value_counts(normalize=True))
    sns.countplot(x=col, data=df);
    plt.show()

# %%
for col in ['pclass', 'sibsp', 'parch', 'embarked', 'sex']:
    explore_categorical(df, col)
# Out:
# ### pclass ###
# pclass
# 3    0.552306
# 1    0.240720
# 2    0.206974
# Name: proportion, dtype: float64
# ### sibsp ###
# sibsp
# 0    0.681665
# 1    0.235096
# 2    0.031496
# 4    0.020247
# 3    0.017998
# 8    0.007874
# 5    0.005624
# Name: proportion, dtype: float64
# ### parch ###
# parch
# 0    0.760405
# 1    0.132733
# 2    0.089989
# 5    0.005624
# 3    0.005624
# 4    0.004499
# 6    0.001125
# Name: proportion, dtype: float64
# ### embarked ###
# embarked
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: proportion, dtype: float64
# ### sex ###
# sex
# male      0.649044
# female    0.350956
# Name: proportion, dtype: float64

# %%
def explore_continuous(df, col):
    print(f'### {col} ###')
    print(df[col].describe())
    sns.histplot(x=col, data=df);
    plt.show()

# %%
for col in ['age', 'fare']:
    explore_continuous(df, col)
# Out:
# ### age ###
# count    889.000000
# mean      29.065433
# std       13.270162
# min        0.420000
# 25%       21.500000
# 50%       26.000000
# 75%       36.000000
# max       80.000000
# Name: age, dtype: float64
# ### fare ###
# count    889.000000
# mean      32.096681
# std       49.697504
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %% [markdown]
# Bivariate Analysis

# %%
df.sample()
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked
# 806         0       1  male  39.0      0      0   0.0        S

# %%
df.groupby('pclass').survived.mean()
# Out:
# pclass
# 1    0.626168
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %% [markdown]
# The higher the class, the higher the survival rate

# %%
# plot class vs survived
sns.barplot(x='pclass', y='survived', data=df);

# %%
sns.barplot(x='pclass', y='survived', data=df, ci=None);
# plot horizontal line for mean
plt.axhline(df.survived.mean(), color='black', linestyle='--');
plt.show()
# Out:
# /tmp/ipython-input-42-3650877100.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='pclass', y='survived', data=df, ci=None);

# %%
# Survival rate for each group
def survival_rate(df, col):
    print(df.groupby(col).survived.mean())
    sns.barplot(x=col, y='survived', data=df, ci=None);
    #plot horizontal line for overall survival rate
    plt.axhline(df.survived.mean(), color='black', linestyle='--')
    plt.show()

# %%
for col in ['pclass', 'sibsp', 'parch', 'embarked', 'sex']:
    survival_rate(df, col)
# Out:
# /tmp/ipython-input-43-2779290449.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='survived', data=df, ci=None);
# pclass
# 1    0.626168
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64
# sibsp
# 0    0.343234
# 1    0.535885
# 2    0.464286
# 3    0.250000
# 4    0.166667
# 5    0.000000
# 8    0.000000
# Name: survived, dtype: float64
# /tmp/ipython-input-43-2779290449.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='survived', data=df, ci=None);
# parch
# 0    0.341716
# 1    0.550847
# 2    0.500000
# 3    0.600000
# 4    0.000000
# 5    0.200000
# 6    0.000000
# Name: survived, dtype: float64
# /tmp/ipython-input-43-2779290449.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='survived', data=df, ci=None);
# embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: survived, dtype: float64
# /tmp/ipython-input-43-2779290449.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='survived', data=df, ci=None);
# sex
# female    0.740385
# male      0.188908
# Name: survived, dtype: float64
# /tmp/ipython-input-43-2779290449.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='survived', data=df, ci=None);

# %%
sns.histplot(x='age', data=df, hue='survived');

# %%
sns.histplot(x='fare', data=df, hue='survived');

# %%
sns.histplot(x='fare', data=df, hue='survived', multiple='stack');

# %%
df_survived = df[df.survived == 1]
df_died = df[df.survived == 0]

# %%
# Subplots for age distribution
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(x='age', data=df_survived, ax=ax[0], kde=True, color='green')
sns.histplot(x='age', data=df_died, ax=ax[1], kde=True, color='red')
ax[0].set_title('Survived')
ax[1].set_title('Died')
plt.show()

# %%
# Subplots for fare distribution
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(x='fare', data=df_survived, ax=ax[0], kde=True, color='green')
sns.histplot(x='fare', data=df_died, ax=ax[1], kde=True, color='red')
ax[0].set_title('Survived')
ax[1].set_title('Died')
plt.show()

# %%
df.describe()[['age', 'fare']]
# Out:
#               age        fare
# count  889.000000  889.000000
# mean    29.065433   32.096681
# std     13.270162   49.697504
# min      0.420000    0.000000
# 25%     21.500000    7.895800
# 50%     26.000000   14.454200
# 75%     36.000000   31.000000
# max     80.000000  512.329200

# %%
sns.boxplot(x='age',data=df);

# %%
sns.boxplot(x='fare',data=df);

# %%
# Remove outliers
def remove_outliers(df, col):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    return df[(df[col] > lower_bound) & (df[col] < upper_bound)]

# %%
df = df[df.fare < 300]
# df = remove_outliers(df, 'fare')

# %%
sns.boxplot(x='fare',data=df);

# %%
df.fare.describe()
# Out:
# count    886.000000
# mean      30.470611
# std       41.155721
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       30.646850
# max      263.000000
# Name: fare, dtype: float64

# %%
# Split Age into groups
df['age_group'] = pd.cut(df.age, bins=[0, 22, 27, 37, 82], labels=['child', 'young', 'adult', 'senior'])

# Split Fare into groups
df['fare_group'] = pd.cut(df.fare, bins=[-0.99, 8, 15, 35, 265], labels=['low', 'medium', 'high', 'very high'])

# %%
for col in ['age_group', 'fare_group']:
    survival_rate(df, col)
# Out:
# age_group
# child     0.450549
# young     0.260000
# adult     0.427184
# senior    0.357488
# Name: survived, dtype: float64
# /tmp/ipython-input-43-2779290449.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby(col).survived.mean())
# /tmp/ipython-input-43-2779290449.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='survived', data=df, ci=None);
# /tmp/ipython-input-43-2779290449.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby(col).survived.mean())
# /tmp/ipython-input-43-2779290449.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='survived', data=df, ci=None);
# fare_group
# low          0.215768
# medium       0.285714
# high         0.446809
# very high    0.611399
# Name: survived, dtype: float64

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue='survived');

# %%
df_numeric = df.select_dtypes(include='number')  # Select only numeric columns before calculating correlation
df_numeric.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.331075 -0.066652 -0.032095  0.083691  0.259188
# pclass   -0.331075  1.000000 -0.410056  0.079490  0.016579 -0.603362
# age      -0.066652 -0.410056  1.000000 -0.248590 -0.174682  0.126314
# sibsp    -0.032095  0.079490 -0.248590  1.000000  0.414844  0.213507
# parch     0.083691  0.016579 -0.174682  0.414844  1.000000  0.265692
# fare      0.259188 -0.603362  0.126314  0.213507  0.265692  1.000000

# %%
df_numeric = df.select_dtypes(include='number')  # Select only numeric columns before calculating correlation with survived
df_numeric.corr()['survived']
# Out:
# survived    1.000000
# pclass     -0.331075
# age        -0.066652
# sibsp      -0.032095
# parch       0.083691
# fare        0.259188
# Name: survived, dtype: float64

# %%
df_numeric=df.select_dtypes(include='number')
plt.figure(figsize=(10, 8))
sns.heatmap(df_numeric.corr(), annot=True);

# %%
sns.barplot(x='pclass', y='survived', hue= 'sex', data=df, ci=None);
# Out:
# /tmp/ipython-input-64-1058057586.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='pclass', y='survived', hue= 'sex', data=df, ci=None);

# %%
sns.barplot(x='embarked', y='survived', hue= 'sex', data=df, ci=None);
# Out:
# /tmp/ipython-input-65-3729839610.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='embarked', y='survived', hue= 'sex', data=df, ci=None);

# %%
# 7 Subplots
fig, ax = plt.subplots(2, 4, figsize=(15, 8))
for i, col in enumerate(['pclass', 'sibsp', 'parch', 'age_group', 'fare_group', 'embarked', 'sex']):
    sns.barplot(x=col, y= 'survived', data=df, ci=None, ax=ax[i//4, i%4])
    ax[i//4, i%4].axhline(df.survived.mean(), color='black', linestyle='--')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-66-1311005070.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y= 'survived', data=df, ci=None, ax=ax[i//4, i%4])
# /tmp/ipython-input-66-1311005070.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y= 'survived', data=df, ci=None, ax=ax[i//4, i%4])
# /tmp/ipython-input-66-1311005070.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y= 'survived', data=df, ci=None, ax=ax[i//4, i%4])
# /tmp/ipython-input-66-1311005070.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y= 'survived', data=df, ci=None, ax=ax[i//4, i%4])
# /tmp/ipython-input-66-1311005070.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y= 'survived', data=df, ci=None, ax=ax[i//4, i%4])
# /tmp/ipython-input-66-1311005070.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y= 'survived', data=df, ci=None, ax=ax[i//4, i%4])
# /tmp/ipython-input-66-1311005070.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y= 'survived', data=df, ci=None, ax=ax[i//4, i%4])

# %%
female_df = df[df.sex == 'female']
male_df = df[df.sex == 'male']

# %%
female_df.survived.value_counts(normalize=True)
# Out:
# survived
# 1    0.73955
# 0    0.26045
# Name: proportion, dtype: float64

# %%
female_df.groupby('pclass').survived.mean()
# Out:
# pclass
# 1    0.967033
# 2    0.921053
# 3    0.500000
# Name: survived, dtype: float64

# %%
type(female_df.groupby('pclass').survived.mean())  # Pandas Series
# Out:
# pandas.core.series.Series

# %%
sns.barplot(x='pclass', y='survived', data=female_df, ci=None);
plt.axhline(female_df.survived.mean(), color='black', linestyle='--')
plt.show()
# Out:
# /tmp/ipython-input-71-3474947662.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='pclass', y='survived', data=female_df, ci=None);

# %%
male_df.survived.value_counts(normalize=True)
# Out:
# survived
# 0    0.813913
# 1    0.186087
# Name: proportion, dtype: float64

# %%
male_df.groupby('pclass').survived.mean()
# Out:
# pclass
# 1    0.358333
# 2    0.157407
# 3    0.135447
# Name: survived, dtype: float64

# %%
sns.barplot(x='pclass', y='survived', data=male_df, ci=None);
plt.axhline(male_df.survived.mean(), color='black', linestyle='--')
# Out:
# /tmp/ipython-input-74-2591017502.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='pclass', y='survived', data=male_df, ci=None);

# %%
sex_class = pd.merge(female_df.groupby('pclass').survived.mean(), male_df.groupby('pclass').survived.mean(), on='pclass')
sex_class
# Out:
#         survived_x  survived_y
# pclass
# 1         0.967033    0.358333
# 2         0.921053    0.157407
# 3         0.500000    0.135447

# %%
sex_class.rename(columns= {'survived_x': 'female_survived', 'survived_y': 'male_survived'}, inplace=True)

# %%
sex_class
# Out:
#         female_survived  male_survived
# pclass
# 1              0.967033       0.358333
# 2              0.921053       0.157407
# 3              0.500000       0.135447

# %%
df.groupby(['pclass','sex']).survived.mean()
# Out:
# pclass  sex
# 1       female    0.967033
#         male      0.358333
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: survived, dtype: float64

# %% [markdown]
# #Insights

# %% [markdown]
# * The higher the class, the higher the survival rate
#
# * The higher the fare, the higher the survival rate
#
# * Females had a higher survival rate

# %%
# !pip freeze > requirements.txt
